# %%
# Which restaurant in Pune has the most number of people visiting?
# This problem can be solved by getting the number of reviews 
# Restaurant in pune has most number of peeople visiting
import numpy as np
import pandas as pd

data = pd.read_json('data.json')
# df = pd.DataFrame(data)

# data

# %%
# We'll access restaurants and do a function on each object and replace it
df = pd.DataFrame(data)
ratings_array = []
cnt = 0
ratingCountSet = set([])
def expenses(val):
    global cnt
    for rest in val['restaurants']: 
        try:
            ratingCountSet.add(val['restaurants'][rest]['rating_count'])
        except:
            continue
    if(cnt == 0) :
        print(val)

    cnt = cnt+1
    return val
    obj = val
    cost = 0
    cnt = 0
    if(type(obj) == float):
        # NaN value preprocessed
        return 0
    
    if('rating' in obj):
        lc_obj = {"name" : obj['name'], "rating": 0 , "address" : "Not in data"}
        try:
            lc_obj['rating'] = float(obj['rating'])
            cnt = cnt+1
            ratings_array.append(lc_obj)
            
        except:
            lc_obj = lc_obj
        
        try:
            lc_obj['address'] = obj['address']
        except:
            lc_obj = lc_obj
        
        return lc_obj
    else:
       return np.nan
        
    
# 11 problem 
df2 = df
df2 = df2['Pune']
# print(df2)
# # print(df2)
df2 = df2.dropna()
# # print(df2)
df2 = pd.DataFrame(df2)
# print(df2)
# print(df3)
df3 = pd.DataFrame(df2)
df3 = df3.drop('link',axis = 0)

df4 = df3['Pune'].apply(expenses)
# print(df3)
# df2 = df2['restaurants'].apply(expenses)
# Out:
# {'link': 'https://www.swiggy.com/city/pune/wanaowrie-restaurants', 'restaurants': {'301765': {'name': 'FARM DA DHABA NH8', 'rating': '--', 'rating_count': 'Too Few Ratings', 'cost': '₹ 350', 'address': 'FARM DA DHABA NH8, Farm Da Dhaba NH8  Country Roads Cafe   Restaurant  Salunke Vihar Road  beside Reliance Fresh  Clover Village  Wanowrie  Pune  Maharashtra  India', 'cuisine': 'Indian', 'lic_no': '11519036000943', 'menu': {'Recommended': {'Chicken 65': {'price': '281', 'veg_or_non_veg': 'Non-veg'}, 'Butter Chicken': {'price': '314', 'veg_or_non_veg': 'Non-veg'}, 'Butter Chicken Biryani': {'price': '345', 'veg_or_non_veg': 'Non-veg'}}, 'Ghar Ka Khana (Veg)': {'3 Chapati and Aloo Bhindi ki Sabji dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Gobi ki Sabji dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Shimla Mirch ki Sabji dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Methi ki Sabji dry': {'price': '179', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Matar ki Sabji dry': {'price': '189', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Gajar Matar ki Sabji dry': {'price': '210', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Bhindi ki Sabji dry': {'price': '220', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Baigan ka Bharta dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Chana Dal & Dudhi ki Sabji': {'price': '189', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Pindi Chole': {'price': '230', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Kadai Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Matar Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Hyderabadi Palak Paneer': {'price': '241', 'veg_or_non_veg': 'Veg'}, 'Ghar ka Mix Veg Pulav with Dahi': {'price': '230', 'veg_or_non_veg': 'Veg'}, 'Dal Khichadi': {'price': '158', 'veg_or_non_veg': 'Veg'}, 'Palak Dal Khichadi': {'price': '178', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Kadhi Pakora': {'price': '157', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Chana Dal & Dudhi ki Sabji': {'price': '189', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Dal Tadka': {'price': '189', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Dal Makhani': {'price': '210', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Pindi Chole': {'price': '210', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Rajma': {'price': '210', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Matar Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Kadai Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Hyderabadi Palak Paneer': {'price': '241', 'veg_or_non_veg': 'Veg'}}, 'Ghar Ka Khana (Non Veg)': {'3 Chapati and  Egg Bhurji': {'price': '157', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Egg Bhurji': {'price': '180', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Egg Curry': {'price': '173', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Egg Curry': {'price': '200', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Butter Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Chicken Keema': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Kadai Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Palak Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Mutton Bhuna': {'price': '262', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Mutton Keema': {'price': '251', 'veg_or_non_veg': 'Non-veg'}, 'Chicken Keema Pav': {'price': '199', 'veg_or_non_veg': 'Non-veg'}, 'Mutton Keema Pav': {'price': '230', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Chicken Keema': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Kadai Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Palak Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Butter Chicken': {'price': '240', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Mutton Keema': {'price': '240', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Mutton Curry ...

# %%
list(ratingCountSet)
# Out:
# ['50+ ratings',
#  '1K+ ratings',
#  '500+ ratings',
#  '20+ ratings',
#  '100+ ratings',
#  'Too Few Ratings']

# %%
# ratingCountSet.remove('NA')
ratingCountSet.remove('Too Few Ratings')
dict = {key : int(key.split()[0].replace('+','').replace('K','000')) for key in list(ratingCountSet)}
dict
# Out:
# {'50+ ratings': 50,
#  '1K+ ratings': 1000,
#  '500+ ratings': 500,
#  '20+ ratings': 20,
#  '100+ ratings': 100}

# %%
dict['NA'] = np.nan
dict['Too Few Ratings'] = 2
dict
# Out:
# {'50+ ratings': 50,
#  '1K+ ratings': 1000,
#  '500+ ratings': 500,
#  '20+ ratings': 20,
#  '100+ ratings': 100,
#  'NA': nan,
#  'Too Few Ratings': 2}

# %%
# We'll access restaurants and do a function on each object and replace it
df = pd.DataFrame(data)
noOfReviews = []
cnt = 0
def expenses(val):
    global cnt
    # val = dict[val]
    obj = val['restaurants']
    if(cnt == 0):
                print(obj)
    
    cnt = cnt+1
    # print(cnt)
    max_lc_obj = {}
    mx = 0
    for ele in obj:
        if(cnt == 1) : 
            print(ele)
        lc_obj = {"name" : obj[ele]['name'], "rating_count": 0 , "address" : "Not in data"}
        try:
            if(dict[obj[ele]['rating_count']] >= mx):
                 mx = dict[obj[ele]['rating_count']]
                 max_lc_obj = lc_obj
            lc_obj['rating_count'] = dict[obj[ele]['rating_count']]
            
            noOfReviews.append(lc_obj)
            
        except:
            lc_obj = lc_obj
        
        try:
            lc_obj['address'] = obj[ele]['address']
        except:
            lc_obj = lc_obj
        
    if(len(max_lc_obj) == 0) :
         return np.nan
    return max_lc_obj
        
# 11 problem 
# print(df3)
df4 = df3['Pune'].apply(expenses)
# Out:
# {'301765': {'name': 'FARM DA DHABA NH8', 'rating': '--', 'rating_count': 'Too Few Ratings', 'cost': '₹ 350', 'address': 'FARM DA DHABA NH8, Farm Da Dhaba NH8  Country Roads Cafe   Restaurant  Salunke Vihar Road  beside Reliance Fresh  Clover Village  Wanowrie  Pune  Maharashtra  India', 'cuisine': 'Indian', 'lic_no': '11519036000943', 'menu': {'Recommended': {'Chicken 65': {'price': '281', 'veg_or_non_veg': 'Non-veg'}, 'Butter Chicken': {'price': '314', 'veg_or_non_veg': 'Non-veg'}, 'Butter Chicken Biryani': {'price': '345', 'veg_or_non_veg': 'Non-veg'}}, 'Ghar Ka Khana (Veg)': {'3 Chapati and Aloo Bhindi ki Sabji dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Gobi ki Sabji dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Shimla Mirch ki Sabji dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Methi ki Sabji dry': {'price': '179', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Aloo Matar ki Sabji dry': {'price': '189', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Gajar Matar ki Sabji dry': {'price': '210', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Bhindi ki Sabji dry': {'price': '220', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Baigan ka Bharta dry': {'price': '200', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Chana Dal & Dudhi ki Sabji': {'price': '189', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Pindi Chole': {'price': '230', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Kadai Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Matar Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, '3 Chapati and Hyderabadi Palak Paneer': {'price': '241', 'veg_or_non_veg': 'Veg'}, 'Ghar ka Mix Veg Pulav with Dahi': {'price': '230', 'veg_or_non_veg': 'Veg'}, 'Dal Khichadi': {'price': '158', 'veg_or_non_veg': 'Veg'}, 'Palak Dal Khichadi': {'price': '178', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Kadhi Pakora': {'price': '157', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Chana Dal & Dudhi ki Sabji': {'price': '189', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Dal Tadka': {'price': '189', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Dal Makhani': {'price': '210', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Pindi Chole': {'price': '210', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Rajma': {'price': '210', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Matar Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Kadai Paneer': {'price': '230', 'veg_or_non_veg': 'Veg'}, 'Steamed Rice and Hyderabadi Palak Paneer': {'price': '241', 'veg_or_non_veg': 'Veg'}}, 'Ghar Ka Khana (Non Veg)': {'3 Chapati and  Egg Bhurji': {'price': '157', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Egg Bhurji': {'price': '180', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Egg Curry': {'price': '173', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Egg Curry': {'price': '200', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Butter Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Chicken Keema': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Kadai Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Palak Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Mutton Bhuna': {'price': '262', 'veg_or_non_veg': 'Non-veg'}, '3 Chapati and Mutton Keema': {'price': '251', 'veg_or_non_veg': 'Non-veg'}, 'Chicken Keema Pav': {'price': '199', 'veg_or_non_veg': 'Non-veg'}, 'Mutton Keema Pav': {'price': '230', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Chicken Keema': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Kadai Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Palak Chicken': {'price': '241', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Butter Chicken': {'price': '240', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Mutton Keema': {'price': '240', 'veg_or_non_veg': 'Non-veg'}, 'Steamed Rice and Mutton Curry': {'price': '262', 'veg_or_non_veg': 'Non-veg'}, 'Tunde Kebab (2 Piece) + 1 Butte ...
# 301765
# 125737
# 495081
# 38123
# 100570
# 505357
# 572527
# 397663
# 37515
# 75808
# 454048
# 549709

# %%
df5 = df4.dropna()
df5
# Out:
# Wanowrie             {'name': 'Ahad', 'rating_count': 2, 'address':...
# Koregaon Park        {'name': 'THE CHICKSTER- Fried Chicken', 'rati...
# Hadapsar             {'name': 'Hotel Garwa Satyampuram (Veg & NonVe...
# Warje                {'name': 'Aroma's Hyderabad House(Warje)', 'ra...
# Pimple Saudagar      {'name': 'Burger King', 'rating_count': 1000, ...
# Kothrud              {'name': 'Green Food', 'rating_count': 1000, '...
# Vishrantwadi         {'name': 'RK Pure Veg', 'rating_count': 500, '...
# Sangvi               {'name': 'McDonald's', 'rating_count': 500, 'a...
# Bibwewadi            {'name': 'The Chinese Monk', 'rating_count': 1...
# Wakad                {'name': 'Apricot Veg', 'rating_count': 1000, ...
# Kondhwa              {'name': 'Uncle's Chinese', 'rating_count': 10...
# Swargate             {'name': 'PK Biryani House (Swargate)', 'ratin...
# Nigdi                {'name': 'Krishna Veg', 'rating_count': 1000, ...
# Bavdhan              {'name': 'Uncle's Chinese', 'rating_count': 10...
# Bhosari              {'name': 'Rolls Mania', 'rating_count': 500, '...
# Sinhgad Road         {'name': 'Brahma Garden', 'rating_count': 1000...
# Wagholi              {'name': 'Shangri-La Kamalbaug', 'rating_count...
# Narhe                {'name': 'Shreeji Pure Veg (Narhe)', 'rating_c...
# Hinjewadi            {'name': 'Desi Dhaba', 'rating_count': 1000, '...
# Bopodi               {'name': 'bruger bhau', 'rating_count': 2, 'ad...
# PCMC                 {'name': 'Burger King', 'rating_count': 1000, ...
# Dhankawadi           {'name': 'Egg Masters', 'rating_count': 2, 'ad...
# Viman Nagar          {'name': 'Sandwich Express', 'rating_count': 1...
# Aundh                {'name': 'Anna Idli', 'rating_count': 1000, 'a...
# Kalyani Nagar        {'name': 'McDonald's', 'rating_count': 1000, '...
# Kharadi              {'name': 'Chaitanya Paranthas', 'rating_count'...
# Shivaji Nagar        {'name': 'PK Biryani House (Deccan)', 'rating_...
# Hinjewadi Phase-3    {'name': 'Hyderabad House (Phase 3)', 'rating_...
# Baner                {'name': 'Kalyan Bhel', 'rating_count': 1000, ...
# Magarpatta           {'name': 'Apna Punjab', 'rating_count': 1000, ...
# Name: Pune, dtype: object

# %%
df5 = pd.DataFrame(df5)
df5.head()
# Out:
#                                                               Pune
# Wanowrie         {'name': 'Ahad', 'rating_count': 2, 'address':...
# Koregaon Park    {'name': 'THE CHICKSTER- Fried Chicken', 'rati...
# Hadapsar         {'name': 'Hotel Garwa Satyampuram (Veg & NonVe...
# Warje            {'name': 'Aroma's Hyderabad House(Warje)', 'ra...
# Pimple Saudagar  {'name': 'Burger King', 'rating_count': 1000, ...

# %%
def deduction(val):
    print(val)
    obj = val['rating_count']
    return obj
def deduction2(val):
    print(val)
    obj = val['name']
    return obj
def deduction3(val):
    obj = val['address']
    return obj
df5['Address'] = df5['Pune'].apply(deduction3)
df5['Name'] = df5['Pune'].apply(deduction2)
df5['Pune'] = df5['Pune'].apply(deduction)
df5.head()
# Out:
# {'name': 'Ahad', 'rating_count': 2, 'address': 'Ahad, Survey no 17A shop no 10, manish darshan, Fatima nagar, Pune, Pune Cantonment Board, Pune PMC, Maharashtra -'}
# {'name': 'THE CHICKSTER- Fried Chicken', 'rating_count': 100, 'address': 'THE CHICKSTER- Fried Chicken , SHOP NO-3, VASVANI BUILDING, PLOT NO-292, SANGAMWADI, KOREGAON PARK, Aundh, Pune PMC, Maharashtra-411001'}
# {'name': 'Hotel Garwa Satyampuram (Veg & NonVeg)', 'rating_count': 1000, 'address': 'Hotel Garwa Satyampuram (Veg & NonVeg), SR NO. 175/31, A-7, SAPTARANG  AAKASH, SASWAD ROAD, BHEKRAI NAGAR, PHURSUNGI'}
# {'name': "Aroma's Hyderabad House(Warje)", 'rating_count': 1000, 'address': "Aroma's Hyderabad House(Warje), Showroom 101, s r no 116,wall s treet 24,his s a no 4, Ground floor, warje, pune, Pune - 411058"}
# {'name': 'Burger King', 'rating_count': 1000, 'address': 'Burger King, Shop 1b, Ground Floor, Rainbow Plaza, Pinple Saudagar,Pune 411027'}
# {'name': 'Green Food', 'rating_count': 1000, 'address': 'Green Food, Survey 3922, Varad Vinayak Society, D P Road, Near Yashwant Rao Chavan Natyagruha, Kothrud, Pune'}
# {'name': 'RK Pure Veg', 'rating_count': 500, 'address': 'RK Pure Veg, Survey no 89 airport road tingre nagar opp Samruddhi restaurant vishrantwadi'}
# {'name': "McDonald's", 'rating_count': 500, 'address': "McDonald's, McDonald?s Family Restaurant, Mega Mart Dapodi pune, Survey no 365, Situated at Old Mumbai Pune Road, Dapodi, PCMC, Pune 411012."}
# {'name': 'The Chinese Monk', 'rating_count': 1000, 'address': 'The Chinese Monk, 1st floor, Shrihari building, near Padma restaurant, next to Abhiman dairy, Dhankwadi'}
# {'name': 'Apricot Veg', 'rating_count': 1000, 'address': 'Apricot Veg, Shop No.5-6, Cubes Commercial, Sr No.183, Datta Mandir Road, Wakad, Pune'}
# {'name': "Uncle's Chinese", 'rating_count': 1000, 'address': "Uncle's Chinese, Mohit Towers, Sahaney Sujan Park, Lullanagar, Bibvewadi, Pune 411040"}
# {'name': 'PK Biryani House (Swargate)', 'rating_count': 1000, 'address': 'PK Biryani House (Swargate), OPP ASHRAY HOTEL, BESIDES IDEA STORE, MITRAMANDAL CHOWK, SWARGATE'}
# {'name': 'Krishna Veg', 'rating_count': 1000, 'address': 'Krishna Veg, 166, Dr Babasaheb Ambedkar Rd, Sector 25, Pradhikaran, Nigdi, Pimpri-Chinchwad, Maharashtra 411044'}
# {'name': "Uncle's Chinese", 'rating_count': 1000, 'address': "Uncle's Chinese, Plot No 7, Sagar Housing Society, Opposite Bank Of Maharashtra, NDA Road, Bavdhan Khurd"}
# {'name': 'Rolls Mania', 'rating_count': 500, 'address': 'Rolls Mania, SHOP NO 3 GROUND FLOOR,PRIVIA SQUARE NX PRADHIKARAN SECTOR 6,IN FRONT OF SPINE CITY MALL,MOSHI, PUNE 412105'}
# {'name': 'Brahma Garden', 'rating_count': 1000, 'address': 'Brahma Garden, Vishal Height, Manikbaug sinhgad road, Sinhgad Road, Pune'}
# {'name': 'Shangri-La Kamalbaug', 'rating_count': 500, 'address': 'Shangri-La Kamalbaug, 1420, Plot 135, Kamalbaug, Nagar Road, Wagholi, Pune'}
# {'name': 'Shreeji Pure Veg (Narhe)', 'rating_count': 1000, 'address': 'Shreeji Pure Veg (Narhe), Shop 6, Survey 54/7/2, Siddhivinayak Angan, Narhe, Pune'}
# {'name': 'Desi Dhaba', 'rating_count': 1000, 'address': 'Desi Dhaba, NEAR LAXMI CHOWK, MEZZA9 ROAD CONNECTING TO LAXMI CHOWK, MARUNJI ROAD, HINJEWADI PHASE 1, HINJAVADI CITY , MULSHI, PUNE, 411057'}
# {'name': 'bruger bhau', 'rating_count': 2, 'address': 'bruger bhau, HRGJ+2XJ, Aba Kate Nagar, Dapodi, Pimpri-Chinchwad, Maharashtra 411012, India'}
# {'name': 'Burger King', 'rating_count': 1000, 'address': 'Burger King, Shop no 5/6, Foodcourt, Elprocitysquare, Chinchwad gaon, Pune 411033'}
# {'name': 'Egg Masters', 'rating_count': 2, 'address': 'Egg Masters, SHOP NO.2, SMITA HSG COMPLEX, S NO. 74/1/B2, KATRAJ, Dhanakawadi, Pune PMC, , Maharashtra, 411046'}
# {'name': 'Sandwich Express', 'rating_count': 1000, 'address': 'Sandwich Express, Shop number 5 lunkad Plaza society near BSNL office Viman Nagar Pune'}
# {'name': 'Anna Idli', 'rating_count': 1000, 'address': 'Anna Idli, Opposite Aman Honda Showroom, Baner Road, Baner, Pune'}
# {'name': "McDonald's", 'rating_count': 1000, 'address': "McDonald's, Marigold Complex, Gr Floor, Survey No 15, Wadgaon Sheri, Kalyani Nagar Pune."}
# {'name': 'Chaitanya Paranthas', 'rating_count': 1000, 'address': 'Chaitanya Paranthas, Opposite Zensar IT Park, Kharadi, Pune'}
# {'name': 'PK Biryani House (Deccan)', 'rating_count': 1000, 'address': 'PK Biryani House (Deccan), Deccan Gymkhana, Pune, Maharashtra 411004'}
# {'name': 'Hyderabad House (Phase 3)', 'rating_count': 500, 'address': 'Hyderabad House (Phase 3), Opposite Fire Station, Near Megapolis Bus Stop, Phase 3 , IT Park , Hinjewadi , Pune'}
# {'name': 'Kalyan Bhel', 'rating_count': 1000, 'address': 'Kalyan Bhel, Ganaraj chowk opp. Cosmos regency shop no. 1 near mango sweet'}
# {'name': 'Apna Punjab', 'rating_count': 1000, 'address': 'Apna Punjab, S no 140 next to bharat petrol pump near magarpatta city main gate.'}
# {'name': 'Ahad', 'rating_count': 2, 'address': 'Ahad, Survey no 17A shop no 10, manish darshan, Fatima nagar, Pune, Pune Cantonment Board, Pune PMC, Maharashtra -'}
# {'name': 'THE CHICKSTER- Fried Chicken', 'rating_count': 100, 'address': 'THE CHICKSTER- Fried Chicken , SHOP NO-3, VASVANI BUILDING, PLOT NO-292, SANGAMWADI, KOREGAON PARK, Aundh, Pune PMC, Maharashtra-411001'}
# {'name': 'Hotel Garwa Satyampuram (Veg & NonVeg)', 'rating_count': 1000, 'address': 'Hotel Garwa Satyampuram (Veg & NonVeg), SR NO. 175/31, A-7, SAPTARANG  AAKASH, SASWAD ROAD, BHEKRAI NAGAR, PHURSUNGI'}
# {'name': "Aroma's Hyderabad House(Warje)", 'rating_count': 1000, 'address': "Aroma's Hyderabad House(Warje), Showroom 101, s r no 116,wall s treet 24,his s a no 4, Ground floor, warje, pune, Pune - 411058"}
# {'name': 'Burger King', 'rating_count': 1000, 'address': 'Burger King, Shop 1b, Ground Floor, Rainbow Plaza, Pinple Saudagar,Pune 411027'}
# {'name': 'Green Food', 'rating_count': 1000, 'address': 'Green Food, Survey 3922, Varad Vinayak Society, D P Road, Near Yashwant Rao Chavan Natyagruha, Kothrud, Pune'}
# {'name': 'RK Pure Veg', 'rating_count': 500, 'address': 'RK Pure Veg, Survey no 89 airport road tingre nagar opp Samruddhi restaurant vishrantwadi'}
# {'name': "McDonald's", 'rating_count': 500, 'address': "McDonald's, McDonald?s Family Restaurant, Mega Mart Dapodi pune, Survey no 365, Situated at Old Mumbai Pune Road, Dapodi, PCMC, Pune 411012."}
# {'name': 'The Chinese Monk', 'rating_count': 1000, 'address': 'The Chinese Monk, 1st floor, Shrihari building, near Padma restaurant, next to Abhiman dairy, Dhankwadi'}
# {'name': 'Apricot Veg', 'rating_count': 1000, 'address': 'Apricot Veg, Shop No.5-6, Cubes Commercial, Sr No.183, Datta Mandir Road, Wakad, Pune'}
# {'name': "Uncle's Chinese", 'rating_count': 1000, 'address': "Uncle's Chinese, Mohit Towers, Sahaney Sujan Park, Lullanagar, Bibvewadi, Pune 411040"}
# {'name': 'PK Biryani House (Swargate)', 'rating_count': 1000, 'address': 'PK Biryani House (Swargate), OPP ASHRAY HOTEL, BESIDES IDEA STORE, MITRAMANDAL CHOWK, SWARGATE'}
# {'name': 'Krishna Veg', 'rating_count': 1000, 'address': 'Krishna Veg, 166, Dr Babasaheb Ambedkar Rd, Sector 25, Pradhikaran, Nigdi, Pimpri-Chinchwad, Maharashtra 411044'}
# {'name': "Uncle's Chinese", 'rating_count': 1000, 'address': "Uncle's Chinese, Plot No 7, Sagar Housing Society, Opposite Bank Of Maharashtra, NDA Road, Bavdhan Khurd"}
# {'name': 'Rolls Mania', 'rating_count': 500, 'address': 'Rolls Mania, SHOP NO 3 GROUND FLOOR,PRIVIA SQUARE NX PRADHIKARAN SECTOR 6,IN FRONT OF SPINE CITY MALL,MOSHI, PUNE 412105'}
# {'name': 'Brahma Garden', 'rating_count': 1000, 'address': 'Brahma Garden, Vishal Height, Manikbaug sinhgad road, Sinhgad Road, Pune'}
# {'name': 'Shangri-La Kamalbaug', 'rating_count': 500, 'address': 'Shangri-La Kamalbaug, 1420, Plot 135, Kamalbaug, Nagar Road, Wagholi, Pune'}
# {'name': 'Shreeji Pure Veg (Narhe)', 'rating_count': 1000, 'address': 'Shreeji Pure Veg (Narhe), Shop 6, Survey 54/7/2, Siddhivinayak Angan, Narhe, Pune'}
# {'name': 'Desi Dhaba', 'rating_count': 1000, 'address': 'Desi Dhaba, NEAR LAXMI CHOWK, MEZZA9 ROAD CONNECTING TO LAXMI CHOWK, MARUNJI ROAD, HINJEWADI PHASE 1, HINJAVADI CITY , MULSHI, PUNE, 411057'}
# {'name': 'bruger bhau', 'rating_count': 2, 'address': 'bruger bhau, HRGJ+2XJ, Aba Kate Nagar, Dapodi, Pimpri-Chinchwad, Maharashtra 411012, India'}
# {'name': 'Burger King', 'rating_count': 1000, 'address': 'Burger King, Shop no 5/6, Foodcourt, Elprocitysquare, Chinchwad gaon, Pune 411033'}
# {'name': 'Egg Masters', 'rating_count': 2, 'address': 'Egg Masters, SHOP NO.2, SMITA HSG COMPLEX, S NO. 74/1/B2, KATRAJ, Dhanakawadi, Pune PMC, , Maharashtra, 411046'}
# {'name': 'Sandwich Express', 'rating_count': 1000, 'address': 'Sandwich Express, Shop number 5 lunkad Plaza society near BSNL office Viman Nagar Pune'}
# {'name': 'Anna Idli', 'rating_count': 1000, 'address': 'Anna Idli, Opposite Aman Honda Showroom, Baner Road, Baner, Pune'}
# {'name': "McDonald's", 'rating_count': 1000, 'address': "McDonald's, Marigold Complex, Gr Floor, Survey No 15, Wadgaon Sheri, Kalyani Nagar Pune."}
# {'name': 'Chaitanya Paranthas', 'rating_count': 1000, 'address': 'Chaitanya Paranthas, Opposite Zensar IT Park, Kharadi, Pune'}
# {'name': 'PK Biryani House (Deccan)', 'rating_count': 1000, 'address': 'PK Biryani House (Deccan), Deccan Gymkhana, Pune, Maharashtra 411004'}
# {'name': 'Hyderabad House (Phase 3)', 'rating_count': 500, 'address': 'Hyderabad House (Phase 3), Opposite Fire Station, Near Megapolis Bus Stop, Phase 3 , IT Park , Hinjewadi , Pune'}
# {'name': 'Kalyan Bhel', 'rating_count': 1000, 'address': 'Kalyan Bhel, Ganaraj chowk opp. Cosmos regency shop no. 1 near mango sweet'}
# {'name': 'Apna Punjab', 'rating_count': 1000, 'address': 'Apna Punjab, S no 140 next to bharat petrol pump near magarpatta city main gate.'}
#                  Pune                                            Address
# Wanowrie            2  Ahad, Survey no 17A shop no 10, manish darshan...  \
# Koregaon Park     100  THE CHICKSTER- Fried Chicken , SHOP NO-3, VASV...
# Hadapsar         1000  Hotel Garwa Satyampuram (Veg & NonVeg), SR NO....
# Warje            1000  Aroma's Hyderabad House(Warje), Showroom 101, ...
# Pimple Saudagar  1000  Burger King, Shop 1b, Ground Floor, Rainbow Pl...
#
#                                                    Name
# Wanowrie                                           Ahad
# Koregaon Park              THE CHICKSTER- Fried Chicken
# Hadapsar         Hotel Garwa Satyampuram (Veg & NonVeg)
# Warje                    Aroma's Hyderabad House(Warje)
# Pimple Saudagar                             Burger King

# %%
df6 = df5.sort_values(by='Pune' , ascending = False)
df6.rename(columns = {'Pune':'Ratings'}, inplace = True)

df6[:10]
# Out:
#                Ratings                                            Address
# Sinhgad Road      1000  Brahma Garden, Vishal Height, Manikbaug sinhga...  \
# Nigdi             1000  Krishna Veg, 166, Dr Babasaheb Ambedkar Rd, Se...
# Baner             1000  Kalyan Bhel, Ganaraj chowk opp. Cosmos regency...
# Shivaji Nagar     1000  PK Biryani House (Deccan), Deccan Gymkhana, Pu...
# Kharadi           1000  Chaitanya Paranthas, Opposite Zensar IT Park, ...
# Kalyani Nagar     1000  McDonald's, Marigold Complex, Gr Floor, Survey...
# Aundh             1000  Anna Idli, Opposite Aman Honda Showroom, Baner...
# Viman Nagar       1000  Sandwich Express, Shop number 5 lunkad Plaza s...
# PCMC              1000  Burger King, Shop no 5/6, Foodcourt, Elprocity...
# Hinjewadi         1000  Desi Dhaba, NEAR LAXMI CHOWK, MEZZA9 ROAD CONN...
#
#                                     Name
# Sinhgad Road               Brahma Garden
# Nigdi                        Krishna Veg
# Baner                        Kalyan Bhel
# Shivaji Nagar  PK Biryani House (Deccan)
# Kharadi              Chaitanya Paranthas
# Kalyani Nagar                 McDonald's
# Aundh                          Anna Idli
# Viman Nagar             Sandwich Express
# PCMC                         Burger King
# Hinjewadi                     Desi Dhaba

# %% [markdown]
# Which restaurant in Pune has the most number of people visiting?
#
# 	Brahma Garden, Vishal Height, Manikbaug sinhga...	Brahma Garden
#
#     Krishna Veg, 166, Dr Babasaheb Ambedkar Rd, Se...	Krishna Veg
#
#     Kalyan Bhel, Ganaraj chowk opp. Cosmos regency...	Kalyan Bhel
#
# 	PK Biryani House (Deccan), Deccan Gymkhana, Pu...	PK Biryani House (Deccan)
#
#     Chaitanya Paranthas, Opposite Zensar IT Park, ...	Chaitanya Paranthas
#
# 	McDonald's, Marigold Complex, Gr Floor, Survey...	McDonald's
#
#     Aundh	1000	Anna Idli, Opposite Aman Honda Showroom, Baner...	Anna Idli
#
# 	Sandwich Express, Shop number 5 lunkad Plaza s...	Sandwich Express
#
#     Burger King, Shop no 5/6, Foodcourt, Elprocity...	Burger King
#
#     Desi Dhaba, NEAR LAXMI CHOWK, MEZZA9 ROAD CONN...	Desi Dhaba
