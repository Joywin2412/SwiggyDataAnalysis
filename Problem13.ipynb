# %%
import numpy as np
import pandas as pd

data = pd.read_json('data.json')
# df = pd.DataFrame(data)

# data

# %%
# We'll access restaurants and do a function on each object and replace it
df = pd.DataFrame(data)
ratings_array = []
def expenses(val):
    print(val)
    obj = val
    # obj = obj['restaurants']
    cost = 0
    cnt = 0
    if(type(obj) == float):
        # NaN value preprocessed
        return 0
    
    if('rating' in obj):
        lc_obj = {"name" : obj['name'], "rating": 0 , "address" : "Not in data"}
        try:
            lc_obj['rating'] = float(obj['rating'])
            cnt = cnt+1
            ratings_array.append(lc_obj)
            
        except:
            lc_obj = lc_obj
        
        try:
            lc_obj['address'] = obj['address']
        except:
            lc_obj = lc_obj
        
        return lc_obj
    else:
       return np.nan
        
    
# 12 problem 
df2 = df
df2 = df2['Patna']
# print(df2)
df2 = df2.iloc[1]
# print(df2)
df2 = pd.DataFrame(df2)
# print(df2)
df2 = df2.transpose()
df2 = df2.sort_values(by = 'rating' , ascending = False)
print(df2[:10])
# df2 = df2['restaurants'].apply(expenses)
# Out:
#                                                    name rating rating_count
# 290590  Kwality Walls Frozen Dessert and Ice Cream Shop    4.6  1K+ ratings  \
# 550814                                    Slurpy Shakes    4.6  50+ ratings
# 550713                    Cupcake Bliss Cake & Desserts    4.5  20+ ratings
# 560369                                   GARAGE KITCHEN    4.5  50+ ratings
# 553020                                     Burger It Up    4.5  20+ ratings
# 561789                      Kouzina Kafe The Food Court    4.5  50+ ratings
# 561782                                  Indiana Burgers    4.4  50+ ratings
# 492420                       Pure Veg Meals by Lunchbox    4.4  20+ ratings
# 469839                                 KINGDOM OF MOMOS    4.4  50+ ratings
# 550907                                 The Dessert Zone    4.4  50+ ratings
#
#          cost                                            address
# 290590  ₹ 100  Kwality Walls Frozen Dessert and Ice Cream Sho...  \
# 550814  ₹ 150  Slurpy Shakes, Ground Floor, Old Dr.Zakir Huss...
# 550713  ₹ 200  Cupcake Bliss Cake & Desserts, Ground Floor, O...
# 560369  ₹ 300  GARAGE KITCHEN, H5VF+88R, Mahatma Gandhi Nagar...
# 553020  ₹ 200  Burger It Up, """Ground Floor, Old Dr.Zakir Hu...
# 561789  ₹ 200  Kouzina Kafe The Food Court, Ground Floor, Old...
# 561782  ₹ 200  Indiana Burgers, Ground Floor, Old Dr.Zakir Hu...
# 492420  ₹ 200  Pure Veg Meals by Lunchbox, 8B, SHAKRA HOUSE, ...
# 469839  ₹ 400  KINGDOM OF MOMOS, chunni plaza near NMC colleg...
# 550907  ₹ 200  The Dessert Zone, Ground Floor, Old Dr.Zakir H...
#
#                       cuisine          lic_no
# 290590     Desserts,Ice Cream  10420000000173  \
# 550814    Beverages,Ice Cream  10422000001105
# 550713        Bakery,Desserts  10422000001105
# 560369      Italian,Fast Food  20422001000305
# 553020   American,Continental  10422000001105
# 561789        Bakery,Desserts  10422000001105
# 561782     Fast Food,American  10422000001105
# 492420  North Indian,Desserts  10422000000291
# 469839        Chinese,Tandoor  20421001001151
# 550907        Bakery,Desserts  10422000001105
#
#                                                      menu
# 290590  {'Recommended': {'Chocolate': {'price': '145',...  \
# 550814  {'Recommended': {'Chocolatey Combo': {'price':...
# 550713  {'Recommended': {'Choco Butterscotch Bento Cak...
# 560369  {'Beverages': {'Sprite Canl]': {'price': ...
# 553020  {'Recommended': {'4 Chicken Burger+2 Fries+2 C...
# 561789  {'Recommended': {'Paneer Burger': {'price': '2...
# 561782  {'Recommended': {'Paneer Burger': {'price': '2...
# 492420  {'Recommended': {'Dal Makhani and Paratha Lunc...
# 469839  {'Combo': {'Veg Steamed Momos + Veg Soup': {'p...
# 550907  {'Recommended': {'Pink Pinata Cake-Eggless': {...
#
#                                                      link type price
# 290590  https://www.swiggy.com/restaurants/kwality-wal...  NaN   NaN
# 550814  https://www.swiggy.com/restaurants/slurpy-shak...  NaN   NaN
# 550713  https://www.swiggy.com/restaurants/cupcake-bli...  NaN   NaN
# 560369  https://www.swiggy.com/restaurants/garage-kitc...  NaN   NaN
# 553020  https://www.swiggy.com/restaurants/burger-it-u...  NaN   NaN
# 561789  https://www.swiggy.com/restaurants/kouzina-kaf...  NaN   NaN
# 561782  https://www.swiggy.com/restaurants/indiana-bur...  NaN   NaN
# 492420  https://www.swiggy.com/restaurants/pure-veg-me...  NaN   NaN
# 469839  https://www.swiggy.com/restaurants/kingdom-of-...  NaN   NaN
# 550907  https://www.swiggy.com/restaurants/the-dessert...  NaN   NaN

# %% [markdown]
# Problem 13 : Top 10 Restaurant in Patna w.r.t rating
#
# Kwality Walls Frozen Dessert and Ice Cream Shop    4.6
# Slurpy Shakes    4.6
# Cupcake Bliss Cake & Desserts    4.5
# GARAGE KITCHEN    4.5
# Burger It Up    4.5
# Kouzina Kafe The Food Court    4.5
# Indiana Burgers    4.4
# Pure Veg Meals by Lunchbox    4.4
# KINGDOM OF MOMOS    4.4
# The Dessert Zone    4.4
